# %%
# !pip install seaborn -q 2>&1
print("✓ seaborn installé avec succès") if 'seaborn' in locals() else print("✗ Échec de l'installation")
# Out:
# ✗ Échec de l'installation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# === Chargement des données ===
df = pd.read_csv("../data/cleaned/donnees_climat_evaporation.csv")
print(f"Données chargées : {df.shape[0]} lignes, {df.shape[1]} colonnes")
# Out:
# Données chargées : 7308 lignes, 18 colonnes

# %%
print("\n🔍 Aperçu des 5 premières lignes :")
display(df.head())

print("\nℹ️ Informations générales sur les colonnes :")
df.info()

print("\n📊 Statistiques descriptives (variables numériques) :")
display(df.describe())
# Out:
# 🔍 Aperçu des 5 premières lignes :
#       Station  Annee  Mois  Jour  Pluie  Insolation  TCM=(Tmin+Tmax)/2  \
# 0  Ouahigouya   2020     1     1    0.0        10.5               23.5
# 1  Ouahigouya   2020     1     1    0.0        10.5               23.5
# 2  Ouahigouya   2020     1     2    0.0         7.8               21.2
# 3  Ouahigouya   2020     1     2    0.0         7.8               21.2
# 4  Ouahigouya   2020     1     3    0.0         8.5               19.0
#
#    TDM= moyenne des valeurs trihoraires  TMAX  TMIN  Humidité relative MAX  \
# 0                                  23.4  31.0  16.0                     38
# 1                                  23.4  31.0  16.0                     38
# 2                                  20.5  26.4  15.9                     27
# 3                                  20.5  26.4  15.9                     27
# 4                                  19.2  25.1  12.9                     26
#
# ...

# %%
print("📉 Distribution des variables numériques :")
df.select_dtypes(include='number').hist(bins=30, figsize=(14,10), color="#1f77b4", edgecolor='black')
plt.suptitle("Distribution des variables", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# 📉 Distribution des variables numériques :

# %%
print("🔗 Calcul de la matrice de corrélation...")

corr = df.select_dtypes(include='number').corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title("Matrice de corrélation entre les variables numériques", fontsize=16)
plt.show()
# Out:
# 🔗 Calcul de la matrice de corrélation...

# %%
print("📌 Corrélations les plus fortes avec 'Evap_estimee' :")
display(corr['Evap_estimee'].sort_values(ascending=False))
# Out:
# 📌 Corrélations les plus fortes avec 'Evap_estimee' :
# Evap_estimee                            1.000000
# TMAX                                    0.830613
# Insolation                              0.716917
# TDM= moyenne des valeurs trihoraires    0.595456
# TCM=(Tmin+Tmax)/2                       0.576000
# TCM                                     0.576000
# TMIN                                    0.151387
# Vitesse_moy                             0.099549
# Annee                                  -0.003078
# Jour                                   -0.016427
# Pluie_moy_voisine                      -0.310874
# Pluie                                  -0.358712
# Mois                                   -0.359887
# Humidité relative MAX                  -0.796817
# Humidite_moy                           -0.861892
# Humidité relative MIN                  -0.891682
# Name: Evap_estimee, dtype: float64

# %%
# Choisir quelques variables explicatives pertinentes
vars_explicatives = ['Insolation', 'TCM=(Tmin+Tmax)/2', 'Vitesse_moy', 'Humidité relative MIN']

print("📈 Graphiques de dispersion pour analyser visuellement les relations avec 'Evap_estimee'")

for var in vars_explicatives:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(x=var, y='Evap_estimee', data=df, alpha=0.5)
    plt.title(f"Evap_estimee en fonction de {var}")
    plt.xlabel(var)
    plt.ylabel("Evap_estimee (mm/jour)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# 📈 Graphiques de dispersion pour analyser visuellement les relations avec 'Evap_estimee'
